# %%
import numpy as np
import pandas as pd

scores = np.random.randint(40, high=101, size=(50, 5))
scores_df = pd.DataFrame(scores,
    columns=['國文', '英文', '數學', '地理', '歷史'],
    index=range(1,51))
scores_df.index.name = "學號"
scores_df.columns.name="科目"
sum_series = scores_df.sum(axis=1)
mean_series = scores_df.mean(axis=1)
#display(sum_series)
rank_series = sum_series.rank(method='min',ascending=False)
scores_df["總分"] = sum_series
scores_df["平均"] = mean_series
scores_df["名次"] = rank_series
scores_df.sort_values(by='名次')
# Out:
# 科目  國文   英文   數學   地理   歷史   總分    平均    名次
# 學號
# 24  50   81  100  100   93  424  84.8   1.0
# 37  99   70   94   91   58  412  82.4   2.0
# 10  75   96   80   75   86  412  82.4   2.0
# 20  85   61   97   71   96  410  82.0   4.0
# 31  94   89   91   75   59  408  81.6   5.0
# 13  55   77   82   93   98  405  81.0   6.0
# 28  70   93   63   82   95  403  80.6   7.0
# 29  95   75   90   84   58  402  80.4   8.0
# 46  69   80   67   90   88  394  78.8   9.0
# 50  99  100   73   75   42  389  77.8  10.0
# 27  67   75   54  100   91  387  77.4  11.0
# 19  96   88   68   76   51  379  75.8  12.0
# 40  49   99   50   79   91  368  73.6  13.0
# 12  75   42   80   95   74  366  73.2  14.0
# 7   83   68   63   77   75  366  73.2  14.0
# 44  63   95   47   63   97  365  73.0  16.0
# 17  86   79   73   40   84  362  72.4  17.0
# 25  70   40  100   50  100  360  72.0  18.0
# 2   75   83   81   66   54  359  71.8  19.0
# 15  72   44   94   55   91  356  71.2  20.0
# 14  67   81   73   85   44  350  70.0  21.0
# 48  45   92   74   78   60  349  69.8  22.0
# 47  89   53   88   41   78  349  69.8  22.0
# 21  91   72   61   55   68  347  69.4  24.0
# 8   85   71   70   78   43  347  69.4  24.0
# 41  53   76   71   65   77  342  68.4  26.0
# 36  77   87   42   49   87  342  68.4  26.0
# 3   63   52   70   85   70  340  68.0  28.0
# 26  90   51   41   92   63  337  67.4  29.0
# 11  71   58   69   46   92  336  67.2  30.0
# 49  87   46   93   46   60  332  66.4  31.0
# 42  77   59   71   71   54  332  66.4  31.0
# 16  60   45   57   73   95  330  66.0  33.0
# 34  95   45   55   66   69  330  66.0  33.0
# 33  61   57   74   93   44  329  65.8  35.0
# 38  48   71   76   41   90  326  65.2  36.0
# 23  52   91   59   84   40  326  65.2  36.0
# 4   47   61   90   58   68  324  64.8  38.0
# 39  94   41   44   97   43  319  63.8  39.0
# 18  95   54   42   76   50  317  63.4  40.0
# 22  77   51   78   66   44  316  63.2  41.0
# 43  68   46   70   78   53  315  63.0  42.0
# 45  62   51   45   85   70  313  62.6  43.0
# 6   55   64   55   49   85  308  61.6  44.0
# 32  52   62   58   59   71  302  60.4  45.0
# 30  45   43   40   90   83  301  60.2  46.0
# 9   40   70   48   95   40  293  58.6  47.0
# 35  45   97   58   50   41  291  58.2  48.0
# 1   55   72   45   62   56  290  58.0  49.0
# 5   69   47   44   52   66  278  55.6  50.0
